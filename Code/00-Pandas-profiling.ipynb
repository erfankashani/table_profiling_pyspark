# %% [markdown]
# # Pandas Profiling

# %% [markdown]
# In this notebook we discover the pandas_profiling library to understand its capabilities and limitations

# %%
# Add the libraries
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
# read the dataset
filepath='../Data/'+'data_paper_sample_10k.csv'
panda_df = pd.read_csv(filepath)
panda_df
# Out:
#      Unnamed: 0       id                                            authors  \
# 0             0    75067  [{'name': 'Narciso Cerpa', 'id': 2571766951}, ...
# 1             1    40449  [{'name': 'José Luis Martín', 'id': 2322634291...
# 2             2    73220  [{'name': 'John F. Duff', 'id': 2670839461}, {...
# 3             3   136660  [{'name': 'Junji Tomita', 'id': 2097955466}, {...
# 4             4   155019  [{'name': 'Giuseppe Attardi', 'id': 1557751177...
# ..          ...      ...                                                ...
# 286         286  8763005  [{'name': 'Victor W. Marek', 'id': 1989537430}...
# 287         287  8793079  [{'name': 'Eike Schallehn', 'org': 'Otto von G...
# 288         288  8848334  [{'name': 'George Demiris', 'id': 239600869}, ...
# 289         289  8858447  [{'name': 'Phil D. Green', 'id': 2142460826}, ...
# 290         290  8870360  [{'name': 'Bimal Metha', 'org': 'GOOGLE', 'id'...
#
# ...

# %%
profile = ProfileReport(panda_df, title="Pandas Profiling Report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/30 [00:00<?, ?it/s]
# /Users/erfankashani/opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/model/correlations.py:210: RuntimeWarning: invalid value encountered in greater_equal
#   bool_index = abs(correlation_matrix.values) >= threshold
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
